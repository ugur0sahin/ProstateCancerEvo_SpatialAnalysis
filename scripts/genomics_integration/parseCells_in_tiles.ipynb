# %%
import sopa
import spatialdata


sdata = spatialdata.read_zarr("/Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.CellsAdded.zarr")
sdata
# Out:
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# SpatialData object, with associated Zarr store: /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.CellsAdded.zarr
# ├── Images
# │     └── '_20221020095443.ome': DataTree[cyx] (3, 114243, 79178), (3, 28560, 19794), (3, 7140, 4948), (3, 1785, 1237), (3, 446, 309)
# ├── Points
# │     └── 'ARMS_Marks': DataFrame with shape: (<Delayed>, 2) (2D points)
# └── Shapes
#       ├── 'cell_boundaries': GeoDataFrame shape: (299769, 1) (2D shapes)
#       └── 'tiles': GeoDataFrame shape: (2109, 4) (2D shapes)
# with coordinate systems:
#     ▸ 'aligned', with elements:
#         _20221020095443.ome (Images), cell_boundaries (Shapes), tiles (Shapes)
#     ▸ 'global', with elements:
#         cell_boundaries (Shapes)
#     ▸ 'pixels', with elements:
#         _20221020095443.ome (Images), ARMS_Marks (Points), tiles (Shapes)

# %%
import scanpy as sc
Tissue = "Region2"
adata = sc.read_h5ad(f"/Volumes/ProstateCancerEvoMain/dbs/Completed/AllRegions/{Tissue}.raw.annotated.V2.h5ad")

sdata.shapes["cell_boundaries"].index = adata.obs["cell_id"].values

# %%
# import pandas as pd

# around_cells = pd.read_csv("/Users/ugursahin/ProstateCancerEvo_SpatialAnalysis/scripts/genomics_integration/Tiles_In_R2.csv")
# tile_names = around_cells["name"].to_list()

# %%
sdata.shapes["tiles"]["color_joined"] = sdata.shapes["tiles"]["color"].apply(lambda x: "_".join(map(str, x)))

# %%
len(set(sdata.shapes["tiles"]["name"].to_list()))
# Out:
# 289

# %%
from spatialdata import polygon_query

## Run for all
collectedTiles = dict()
for idx in range(sdata.shapes["tiles"].shape[0]):
    try:
        poi, name = sdata["tiles"].geometry.iloc[idx], sdata["tiles"].name.iloc[idx]
        #if name in tile_names:
        col = sdata["tiles"].color.iloc[idx].astype(str)
        color = col[0]+"_"+col[1]+"_"+col[2]

        collectedTiles[str(idx)+"_"+name+"__col_"+color] =  polygon_query(sdata, polygon=poi, target_coordinate_system="aligned").shapes["cell_boundaries"].index.to_list()

        print(idx, name, color)
        #else:
        #    print(f"{name} is skipped, NOT IN R2!")
    except:
        #print(polygon_query(sdata, polygon=poi, target_coordinate_system="aligned"))

        print(f"{name} is skipped, set is EMPTY ! ")
# Out:
# 0 plate4_7B 255_255_255
# 1 plate4_4A 255_255_0
# 2 plate4_11E 102_0_102
# 3 plate4_2D 102_0_102
# 4 plate4_12G 102_0_102
# 5 plate4_5A 102_0_102
# 6 plate4_5A 102_0_102
# plate4_9H is skipped, set is EMPTY !
# 8 plate4_10H 102_0_102
# 9 plate4_8B 255_255_255
# plate4_1D is skipped, set is EMPTY !
# 11 plate4_11E 102_0_102
# 12 plate4_3D 128_0_128
# plate4_7D is skipped, set is EMPTY !
# plate4_12B is skipped, set is EMPTY !
# 15 plate4_10H 102_0_102
# plate4_6D is skipped, set is EMPTY !
# 17 plate4_7C 255_255_0
# 18 plate4_1D 102_0_102
# 19 plate4_5D 255_255_0
# 20 plate4_10C 102_0_102
# 21 plate4_1B 255_255_0
# 22 plate4_7B 255_255_255
# 23 plate4_12F 102_0_102
# 24 plate4_11H 102_0_102
# 25 plate4_12A 102_0_102
# 26 plate4_5C 102_0_102
# 27 plate4_12D 102_0_102
# plate4_9C is skipped, set is EMPTY !
# 29 plate4_8C 102_0_102
# 30 plate4_12E 255_255_0
# 31 plate4_3E 102_0_102
# plate4_7H is skipped, set is EMPTY !
# 33 plate4_1G 255_255_0
# 34 plate4_2E 102_0_102
# 35 plate4_8G 0_255_0
# 36 plate4_9E 102_0_102
# plate4_1H is skipped, set is EMPTY !
# 38 plate4_5H 102_0_102
# 39 plate4_8B 255_255_255
# plate4_9F is skipped, set is EMPTY !
# plate4_4D is skipped, set is EMPTY !
# 42 plate4_5G 102_0_102
# 43 plate4_11G 102_0_102
# plate4_6A is skipped, set is EMPTY !
# plate4_10F is skipped, set is EMPTY !
# 46 plate4_9G 255_255_255
# 47 plate4_11D 102_0_102
# plate4_1A is skipped, set is EMPTY !
# 49 plate4_2D 102_0_102
# 50 plate4_7F 255_255_255
# plate4_10F is skipped, set is EMPTY !
# 52 plate4_10B 102_0_102
# 53 plate4_5E 255_255_0
# 54 plate4_5G 102_0_102
# 55 plate4_11F 102_0_102
# 56 plate4_5F 102_0_102
# 57 plate4_12D 102_0_102
# 58 plate4_6C 102_0_102
# 59 plate4_2G 102_0_102
# plate4_7A is skipped, set is EMPTY !
# 61 plate4_11A 102_0_102
# 62 plate4_12E 255_255_0
# 63 plate4_6H 0_255_0
# 64 plate4_1F 102_0_102
# 65 plate4_2G 102_0_102
# plate4_7E is skipped, set is EMPTY !
# 67 plate4_1G 255_255_0
# plate4_10G is skipped, set is EMPTY !
# 69 plate4_3D 128_0_128
# 70 plate4_1E 255_255_0
# 71 plate4_10E 102_0_102
# 72 plate4_4E 128_0_128
# plate4_11B is skipped, set is EMPTY !
# 74 plate4_12F 102_0_102
# plate4_7E is skipped, set is EMPTY !
# 76 plate4_6G 102_0_102
# 77 plate4_6C 102_0_102
# 78 plate4_1A 102_0_102
# 79 plate4_8B 255_255_255
# 80 plate4_3H 102_0_102
# 81 plate4_6C 102_0_102
# 82 plate4_11G 102_0_102
# plate4_6F is skipped, set is EMPTY !
# plate4_6A is skipped, set is EMPTY !
# 85 plate4_3G 102_0_102
# plate4_10F is skipped, set is EMPTY !
# 87 plate4_3G 102_0_102
# plate4_2C is skipped, set is EMPTY !
# plate4_10G is skipped, set is EMPTY !
# plate4_9C is skipped, set is EMPTY !
# 91 plate4_5H 102_0_102
# 92 plate4_5H 102_0_102
# 93 plate4_6B 0_255_0
# 94 plate4_9D 102_0_102
# 95 plate4_4G 102_0_102
# 96 plate4_8H 102_0_102
# 97 plate4_9A 255_255_255
# 98 plate4_1E 255_255_0
# plate4_7H is skipped, set is EMPTY !
# 100 plate4_2F 102_0_102
# 101 plate4_11A 102_0_102
# 102 plate4_12C 0_255_0
# 103 plate4_2E 102_0_102
# 104 plate4_2G 102_0_102
# 105 plate4_12C 0_255_0
# 106 plate4_4F 255_255_0
# plate4_8E is skipped, set is EMPTY !
# 108 plate4_5D 255_255_0
# plate4_8E is skipped, set is EMPTY !
# plate4_8F is skipped, set is EMPTY !
# 111 plate4_1G 255_255_0
# 112 plate4_1A 102_0_102
# plate4_2B is skipped, set is EMPTY !
# 114 plate4_3G 102_0_102
# plate4_3C is skipped, set is EMPTY !
# 116 plate4_11D 102_0_102
# 117 plate4_3E 102_0_102
# 118 plate4_8G 0_255_0
# 119 plate4_2F 102_0_102
# 120 plate4_10H 102_0_102
# plate4_6A is skipped, set is EMPTY !
# 122 plate4_6E 0_0_0
# plate4_9H is skipped, set is EMPTY !
# plate4_6F is skipped, set is EMPTY !
# 125 plate4_7G 255_255_0
# 126 plate4_10C 102_0_102
# 127 plate4_6G 102_0_102
# plate4_7A is skipped, set is EMPTY !
# plate4_7D is skipped, set is EMPTY !
# plate4_1A is skipped, set is EMPTY !
# plate4_11B is skipped, set is EMPTY !
# 132 plate4_3H 102_0_102
# 133 plate4_11H 102_0_102
# 134 plate4_2E 102_0_102
# 135 plate4_5G 102_0_102
# 136 plate4_8D 0_255_0
# 137 plate4_10C 102_0_102
# plate4_9C is skipped, set is EMPTY !
# plate4_2C is skipped, set is EMPTY !
# 140 plate4_11F 102_0_102
# 141 plate4_6G 102_0_102
# 142 plate4_12C 0_255_0
# plate4_10G is skipped, set is EMPTY !
# 144 plate4_8G 0_255_0
# plate4_4D is skipped, set is EMPTY !
# plate4_6D is skipped, set is EMPTY !
# plate4_4D is skipped, set is EMPTY !
# 148 plate4_6C 102_0_102
# 149 plate4_3B 102_0_102
# 150 plate4_7B 255_255_255
# 151 plate4_5G 102_0_102
# 152 plate4_3F 255_255_0
# 153 plate4_2H 255_255_255
# plate4_10A is skipped, set is EMPTY !
# 155 plate4_9D 102_0_102
# 156 plate4_5F 102_0_102
# plate4_8A is skipped, set is EMPTY !
# 158 plate4_9G 255_255_255
# plate4_10A is skipped, set is EMPTY !
# 160 plate4_9D 102_0_102
# plate4_9F is skipped, set is EMPTY !
# plate4_3C is skipped, set is EMPTY !
# plate4_11C is skipped, set is EMPTY !
# 164 plate4_9B 102_0_102
# 165 plate4_3B 102_0_102
# plate4_4D is skipped, set is EMPTY !
# 167 plate4_8D 0_255_0
# 168 plate4_12D 102_0_102
# plate4_7E is skipped, set is EMPTY !
# plate4_8F is skipped, set is EMPTY !
# 171 plate4_5E 255_255_0
# plate4_2C is skipped, set is EMPTY !
# 173 plate4_4A 255_255_0
# plate4_3C is skipped, set is EMPTY !
# 175 plate4_5F 102_0_102
# plate4_10A is skipped, set is EMPTY !
# 177 plate4_4H 102_0_102
# 178 plate4_3D 128_0_128
# plate4_1H is skipped, set is EMPTY !
# plate4_4C is skipped, set is EMPTY !
# 181 plate4_3F 255_255_0
# 182 plate4_5E 255_255_0
# 183 plate4_10D 0_255_0
# plate4_7A is skipped, set is EMPTY !
# 185 plate4_10D 0_255_0
# plate4_12B is skipped, set is EMPTY !
# 187 plate4_10D 0_255_0
# 188 plate4_2D 102_0_102
# 189 plate4_12E 255_255_0
# plate4_1H is skipped, set is EMPTY !
# 191 plate4_3A 255_255_255
# 192 plate4_3B 102_0_102
# 193 plate4_6G 102_0_102
# 194 plate4_3B 102_0_102
# 195 plate4_11F 102_0_102
# 196 plate4_12E 255_255_0
# 197 plate4_1E 255_255_0
# 198 plate4_10D 0_255_0
# plate4_4C is skipped, set is EMPTY !
# 200 plate4_2A 255_255_0
# 201 plate4_9B 102_0_102
# 202 plate4_9G 255_255_255
# 203 plate4_11C 102_0_102
# 204 plate4_4E 128_0_128
# plate4_7E is skipped, set is EMPTY !
# 206 plate4_11G 102_0_102
# 207 plate4_5F 102_0_102
# 208 plate4_11A 102_0_102
# 209 plate4_9A 255_255_255
# 210 plate4_10C 102_0_102
# 211 plate4_7C 255_255_0
# 212 plate4_2H 255_255_255
# 213 plate4_9E 102_0_102
# 214 plate4_1D 102_0_102
# 215 plate4_12F 102_0_102
# 216 plate4_11C 102_0_102
# 217 plate4_4H 102_0_102
# 218 plate4_4B 255_255_0
# 219 plate4_3D 128_0_128
# plate4_1H is skipped, set is EMPTY !
# 221 plate4_4G 102_0_102
# plate4_9H is skipped, set is EMPTY !
# 223 plate4_4G 102_0_102
# 224 plate4_3A 255_255_255
# 225 plate4_11C 102_0_102
# 226 plate4_4B 255_255_0
# plate4_12B is skipped, set is EMPTY !
# plate4_8F is skipped, set is EMPTY !
# 229 plate4_4F 255_255_0
# 230 plate4_8C 102_0_102
# 231 plate4_10B 102_0_102
# 232 plate4_4B 255_255_0
# plate4_9F is skipped, set is EMPTY !
# 234 plate4_10E 102_0_102
# 235 plate4_10B 102_0_102
# plate4_2B is skipped, set is EMPTY !
# 237 plate4_12G 102_0_102
# 238 plate4_3A 255_255_255
# 239 plate4_1C 102_0_102
# 240 plate4_1G 255_255_0
# 241 plate4_11E 102_0_102
# 242 plate4_2G 102_0_102
# plate4_10G is skipped, set is EMPTY !
# 244 plate4_8C 102_0_102
# 245 plate4_12D 102_0_102
# 246 plate4_12F 102_0_102
# 247 plate4_8H 102_0_102
# 248 plate4_10E 102_0_102
# plate4_8E is skipped, set is EMPTY !
# 250 plate4_5B 102_0_102
# plate4_10A is skipped, set is EMPTY !
# 252 plate4_9E 102_0_102
# 253 plate4_1C 102_0_102
# 254 plate4_10H 102_0_102
# 255 plate4_10B 102_0_102
# 256 plate4_2A 255_255_0
# plate4_9C is skipped, set is EMPTY !
# 258 plate4_12G 102_0_102
# 259 plate4_12A 102_0_102
# plate4_7D is skipped, set is EMPTY !
# 261 plate4_11H 102_0_102
# 262 plate4_6E 0_0_0
# 263 plate4_2E 102_0_102
# 264 plate4_8G 0_255_0
# plate4_8F is skipped, set is EMPTY !
# 266 plate4_7F 255_255_255
# 267 plate4_3F 255_255_0
# plate4_8A is skipped, set is EMPTY !
# 269 plate4_8D 0_255_0
# 270 plate4_11G 102_0_102
# 271 plate4_1B 255_255_0
# 272 plate4_12A 102_0_102
# 273 plate4_8C 102_0_102
# 274 plate4_7G 255_255_0
# 275 plate4_3E 102_0_102
# 276 plate4_5D 255_255_0
# 277 plate4_11D 102_0_102
# 278 plate4_7C 255_255_0
# 279 plate4_3H 102_0_102
# 280 plate4_1B 255_255_0
# 281 plate4_3E 102_0_102
# 282 plate4_5C 102_0_102
# 283 plate4_3G 102_0_102
# 284 plate4_1F 102_0_102
# plate4_1D is skipped, set is EMPTY !
# 286 plate4_3A 255_255_255
# 287 plate4_plate4_2F 102_0_102
# 288 plate4_4A 255_255_0
# 289 plate4_11A 102_0_102
# 290 plate4_12C 0_255_0
# 291 plate4_1B 255_255_0
# 292 plate4_7F 255_255_255
# 293 plate4_2A 255_255_0
# 294 plate4_5C 102_0_102
# 295 plate4_2H 255_255_255
# 296 plate4_6B 0_255_0
# 297 plate4_9E 102_0_102
# 298 plate4_3F 255_255_0
# 299 plate4_9B 102_0_102
# plate4_12B is skipped, set is EMPTY !
# 301 plate4_2A 255_255_0
# 302 plate4_3C 102_0_102
# 303 plate4_6E 0_0_0
# 304 plate4_4F 255_255_0
# plate4_8A is skipped, set is EMPTY !
# 306 plate4_7B 255_255_255
# 307 plate4_10E 102_0_102
# 308 plate4_4E 128_0_128
# 309 plate4_8B 255_255_255
# plate4_7H is skipped, set is EMPTY !
# 311 plate4_5C 102_0_102
# 312 plate4_2D 102_0_102
# plate4_11B is skipped, set is EMPTY !
# plate4_2B is skipped, set is EMPTY !
# plate4_10F is skipped, set is EMPTY !
# 316 plate4_4F 255_255_0
# plate4_6A is skipped, set is EMPTY !
# 318 plate4_11F 102_0_102
# 319 plate4_6H 0_255_0
# 320 plate4_4G 102_0_102
# 321 plate4_12A 102_0_102
# plate4_4C is skipped, set is EMPTY !
# 323 plate4_2H 255_255_255
# plate4_11B is skipped, set is EMPTY !
# 325 plate4_5B 102_0_102
# 326 plate4_5A 102_0_102
# plate4_6F is skipped, set is EMPTY !
# 328 plate4_8H 102_0_102
# 329 plate4_9A 255_255_255
# plate4_9H is skipped, set is EMPTY !
# 331 plate4_9A 255_255_255
# 332 plate4_8D 0_255_0
# 333 plate4_1F 102_0_102
# 334 plate4_3H 102_0_102
# plate4_6D is skipped, set is EMPTY !
# 336 plate4_7F 255_255_255
# 337 plate4_1C 102_0_102
# 338 plate4_4H 102_0_102
# 339 plate4_9D 102_0_102
# 340 plate4_7G 255_255_0
# 341 plate4_1C 102_0_102
# plate4_6F is skipped, set is EMPTY !
# 343 plate4_6H 0_255_0
# 344 plate4_6H 0_255_0
# 345 plate4_5A 102_0_102
# 346 plate4_11D 102_0_102
# 347 plate4_5H 102_0_102
# plate4_6D is skipped, set is EMPTY !
# 349 plate4_12H-scraped 255_255_0
# 350 plate4_9G 255_255_255
# 351 plate4_11H 102_0_102
# 352 plate4_5B 102_0_102
# 353 plate4_6B 0_255_0
# 354 plate4_5E 255_255_0
# 355 plate4_1F 102_0_102
# 356 plate4_4H 102_0_102
# plate4_8E is skipped, set is EMPTY !
# 358 plate4_7C 255_255_0
# plate4_7A is skipped, set is EMPTY !
# 360 plate4_5D 255_255_0
# 361 plate4_7G 255_255_0
# plate4_8A is skipped, set is EMPTY !
# 363 plate4_4B 255_255_0
# 364 plate4_11E 102_0_102
# 365 plate4_4E 128_0_128
# 366 plate4_4A 255_255_0
# 367 plate4_9B 102_0_102
# plate4_7H is skipped, set is EMPTY !
# plate4_4C is skipped, set is EMPTY !
# 370 plate4_6E 0_0_0
# plate4_9F is skipped, set is EMPTY !
# 372 plate4_2F 102_0_102
# 373 plate4_1E 255_255_0
# 374 plate4_5B 102_0_102
# plate4_2B is skipped, set is EMPTY !
# 376 plate4_8H 102_0_102
# 377 plate4_12G 102_0_102
# plate4_2C is skipped, set is EMPTY !
# plate4_7D is skipped, set is EMPTY !
# 380 plate4_6B 0_255_0
# plate13_6A is skipped, set is EMPTY !
# plate13_6H is skipped, set is EMPTY !
# plate13_9G is skipped, set is EMPTY !
# plate13_11E is skipped, set is EMPTY !
# plate13_7G is skipped, set is EMPTY !
# plate13_7E is skipped, set is EMPTY !
# plate13_3C is skipped, set is EMPTY !
# plate13_4A is skipped, set is EMPTY !
# plate13_2F is skipped, set is EMPTY !
# plate13_3C is skipped, set is EMPTY !
# plate13_4F is skipped, set is EMPTY !
# plate13_11B is skipped, set is EMPTY !
# plate13_3F is skipped, set is EMPTY !
# plate13_12B is skipped, set is EMPTY !
# plate13_6C is skipped, set is EMPTY !
# plate13_7C is skipped, set is EMPTY !
# plate13_11D is skipped, set is EMPTY !
# plate13_1D is skipped, set is EMPTY !
# plate13_4E is skipped, set is EMPTY !
# plate13_3E is skipped, set is EMPTY !
# plate13_11G is skipped, set is EMPTY !
# plate13_6D is skipped, set is EMPTY !
# plate13_8C is skipped, set is EMPTY !
# plate13_2F is skipped, set is EMPTY !
# plate13_2E is skipped, set is EMPTY !
# plate13_10C is skipped, set is EMPTY !
# plate13_7C is skipped, set is EMPTY !
# plate13_11A is skipped, set is EMPTY !
# plate13_4E is skipped, set is EMPTY !
# plate13_6C is skipped, set is EMPTY !
# plate13_9E is skipped, set is EMPTY !
# plate13_5A is skipped, set is EMPTY !
# plate13_8G is skipped, set is EMPTY !
# plate13_10F is skipped, set is EMPTY !
# plate13_7G is skipped, set is EMPTY !
# plate13_5E is skipped, set is EMPTY !
# plate13_11F is skipped, set is EMPTY !
# plate13_2G is skipped, set is EMPTY !
# plate13_2D is skipped, set is EMPTY !
# plate13_6H is skipped, set is EMPTY !
# plate13_8D is skipped, set is EMPTY !
# plate13_10B is skipped, set is EMPTY !
# plate13_8B is skipped, set is EMPTY !
# plate13_8B is skipped, set is EMPTY !
# plate13_8D is skipped, set is EMPTY !
# plate13_11E is skipped, set is EMPTY !
# plate13_1G is skipped, set is EMPTY !
# plate13_4G is skipped, set is EMPTY !
# plate13_6E is skipped, set is EMPTY !
# plate13_8C is skipped, set is EMPTY !
# plate13_11C is skipped, set is EMPTY !
# plate13_9E is skipped, set is EMPTY !
# plate13_5C is skipped, set is EMPTY !
# plate13_6C is skipped, set is EMPTY !
# plate13_7H is skipped, set is EMPTY !
# plate13_5E is skipped, set is EMPTY !
# plate13_8C is skipped, set is EMPTY !
# plate13_8F is skipped, set is EMPTY !
# plate13_8B is skipped, set is EMPTY !
# plate13_2F is skipped, set is EMPTY !
# plate13_10D is skipped, set is EMPTY !
# plate13_9G is skipped, set is EMPTY !
# plate13_7A is skipped, set is EMPTY !
# plate13_7F is skipped, set is EMPTY !
# plate13_12B is skipped, set is EMPTY !
# plate13_10E is skipped, set is EMPTY !
# plate13_4D is skipped, set is EMPTY !
# plate13_3D is skipped, set is EMPTY !
# plate13_9F is skipped, set is EMPTY !
# plate13_4G is skipped, set is EMPTY !
# plate13_3A is skipped, set is EMPTY !
# plate13_1C is skipped, set is EMPTY !
# plate13_8H is skipped, set is EMPTY !
# plate13_8E is skipped, set is EMPTY !
# plate13_11B is skipped, set is EMPTY !
# plate13_7C is skipped, set is EMPTY !
# plate13_5G is skipped, set is EMPTY !
# plate13_3C is skipped, set is EMPTY !
# plate13_1G is skipped, set is EMPTY !
# plate13_2A is skipped, set is EMPTY !
# plate13_6C is skipped, set is EMPTY !
# plate13_1F is skipped, set is EMPTY !
# plate13_2D is skipped, set is EMPTY !
# plate13_7B is skipped, set is EMPTY !
# plate13_3E is skipped, set is EMPTY !
# plate13_6A is skipped, set is EMPTY !
# plate13_3A is skipped, set is EMPTY !
# plate13_5C is skipped, set is EMPTY !
# plate13_8G is skipped, set is EMPTY !
# plate13_7F is skipped, set is EMPTY !
# plate13_11D is skipped, set is EMPTY !
# plate13_6B is skipped, set is EMPTY !
# plate13_4B is skipped, set is EMPTY !
# plate13_11E is skipped, set is EMPTY !
# plate13_11B is skipped, set is EMPTY !
# plate13_6H is skipped, set is EMPTY !
# plate13_7F is skipped, set is EMPTY !
# plate13_4H is skipped, set is EMPTY !
# plate13_12H is skipped, set is EMPTY !
# plate13_6C is skipped, set is EMPTY !
# plate13_7G is skipped, set is EMPTY !
# plate13_11A is skipped, set is EMPTY !
# plate13_1F is skipped, set is EMPTY !
# plate13_11A is skipped, set is EMPTY !
# plate13_7F is skipped, set is EMPTY !
# plate13_4A is skipped, set is EMPTY !
# plate13_4E is skipped, set is EMPTY !
# plate13_3H is skipped, set is EMPTY !
# plate13_6H is skipped, set is EMPTY !
# plate13_5B is skipped, set is EMPTY !
# plate13_6F is skipped, set is EMPTY !
# plate13_4D is skipped, set is EMPTY !
# plate13_8F is skipped, set is EMPTY !
# plate13_10A is skipped, set is EMPTY !
# plate13_4H is skipped, set is EMPTY !
# plate13_10B is skipped, set is EMPTY !
# plate13_12H is skipped, set is EMPTY !
# plate13_1F is skipped, set is EMPTY !
# plate13_10G is skipped, set is EMPTY !
# plate13_1D is skipped, set is EMPTY !
# plate13_8D is skipped, set is EMPTY !
# plate13_3A is skipped, set is EMPTY !
# plate13_3D is skipped, set is EMPTY !
# plate13_1B is skipped, set is EMPTY !
# plate13_2A is skipped, set is EMPTY !
# plate13_8G is skipped, set is EMPTY !
# plate13_4C is skipped, set is EMPTY !
# plate13_5D is skipped, set is EMPTY !
# plate13_9H is skipped, set is EMPTY !
# plate13_11C is skipped, set is EMPTY !
# plate13_3B is skipped, set is EMPTY !
# plate13_7F is skipped, set is EMPTY !
# plate13_8H is skipped, set is EMPTY !
# plate13_11E is skipped, set is EMPTY !
# plate13_9H is skipped, set is EMPTY !
# plate13_6F is skipped, set is EMPTY !
# plate13_5E is skipped, set is EMPTY !
# plate13_11G is skipped, set is EMPTY !
# plate13_12B is skipped, set is EMPTY !
# plate13_10B is skipped, set is EMPTY !
# plate13_7F is skipped, set is EMPTY !
# plate13_10C is skipped, set is EMPTY !
# plate13_4H is skipped, set is EMPTY !
# plate13_2C is skipped, set is EMPTY !
# plate13_9D is skipped, set is EMPTY !
# plate13_11H is skipped, set is EMPTY !
# plate13_6C is skipped, set is EMPTY !
# plate13_2A is skipped, set is EMPTY !
# plate13_5A is skipped, set is EMPTY !
# plate13_12F is skipped, set is EMPTY !
# plate13_6C is skipped, set is EMPTY !
# plate13_8F is skipped, set is EMPTY !
# plate13_12D is skipped, set is EMPTY !
# plate13_5E is skipped, set is EMPTY !
# plate13_8C is skipped, set is EMPTY !
# plate13_10G is skipped, set is EMPTY !
# plate13_2G is skipped, set is EMPTY !
# plate13_2A is skipped, set is EMPTY !
# plate13_1G is skipped, set is EMPTY !
# plate13_9E is skipped, set is EMPTY !
# plate13_12H is skipped, set is EMPTY !
# plate13_10F is skipped, set is EMPTY !
# plate13_2E is skipped, set is EMPTY !
# plate13_8F is skipped, set is EMPTY !
# plate13_1E is skipped, set is EMPTY !
# plate13_7H is skipped, set is EMPTY !
# plate13_4B is skipped, set is EMPTY !
# plate13_5C is skipped, set is EMPTY !
# plate13_3D is skipped, set is EMPTY !
# plate13_2F is skipped, set is EMPTY !
# plate13_9H is skipped, set is EMPTY !
# plate13_9A is skipped, set is EMPTY !
# plate13_7E is skipped, set is EMPTY !
# plate13_12B is skipped, set is EMPTY !
# plate13_3H is skipped, set is EMPTY !
# plate13_4F is skipped, set is EMPTY !
# plate13_4A is skipped, set is EMPTY !
# plate13_3G is skipped, set is EMPTY !
# plate13_4G is skipped, set is EMPTY !
# plate13_1E is skipped, set is EMPTY !
# plate13_5D is skipped, set is EMPTY !
# plate13_12B is skipped, set is EMPTY !
# plate13_11D is skipped, set is EMPTY !
# plate13_10E is skipped, set is EMPTY !
# plate13_1B is skipped, set is EMPTY !
# plate13_6C is skipped, set is EMPTY !
# plate13_10H is skipped, set is EMPTY !
# plate13_3C is skipped, set is EMPTY !
# plate13_2C is skipped, set is EMPTY !
# plate13_6B is skipped, set is EMPTY !
# plate13_6D is skipped, set is EMPTY !
# plate13_10D is skipped, set is EMPTY !
# plate13_4H is skipped, set is EMPTY !
# plate13_9G is skipped, set is EMPTY !
# plate13_5H is skipped, set is EMPTY !
# plate13_7D is skipped, set is EMPTY !
# plate13_7G is skipped, set is EMPTY !
# plate13_5H is skipped, set is EMPTY !
# plate13_2C is skipped, set is EMPTY !
# plate13_2G is skipped, set is EMPTY !
# plate13_12G is skipped, set is EMPTY !
# plate13_9H is skipped, set is EMPTY !
# plate13_8A is skipped, set is EMPTY !
# plate13_5E is skipped, set is EMPTY !
# plate13_11C is skipped, set is EMPTY !
# plate13_11F is skipped, set is EMPTY !
# plate13_7C is skipped, set is EMPTY !
# plate13_12C is skipped, set is EMPTY !
# plate13_3H is skipped, set is EMPTY !
# plate13_8F is skipped, set is EMPTY !
# plate13_5B is skipped, set is EMPTY !
# plate13_7B is skipped, set is EMPTY !
# plate13_5C is skipped, set is EMPTY !
# plate13_3A is skipped, set is EMPTY !
# plate13_5B is skipped, set is EMPTY !
# plate13_12E is skipped, set is EMPTY !
# plate13_5A is skipped, set is EMPTY !
# plate13_5C is skipped, set is EMPTY !
# plate13_12E is skipped, set is EMPTY !
# plate13_5A is skipped, set is EMPTY !
# plate13_6A is skipped, set is EMPTY !
# plate13_6G is skipped, set is EMPTY !
# plate13_12G is skipped, set is EMPTY !
# plate13_7A is skipped, set is EMPTY !
# plate13_5H is skipped, set is EMPTY !
# plate13_3D is skipped, set is EMPTY !
# plate13_10A is skipped, set is EMPTY !
# plate13_4A is skipped, set is EMPTY !
# plate13_1C is skipped, set is EMPTY !
# plate13_4F is skipped, set is EMPTY !
# plate13_8H is skipped, set is EMPTY !
# plate13_11H is skipped, set is EMPTY !
# plate13_10G is skipped, set is EMPTY !
# plate13_4G is skipped, set is EMPTY !
# plate13_10C is skipped, set is EMPTY !
# plate13_7C is skipped, set is EMPTY !
# plate13_9D is skipped, set is EMPTY !
# plate13_3E is skipped, set is EMPTY !
# plate13_10E is skipped, set is EMPTY !
# plate13_5F is skipped, set is EMPTY !
# plate13_12H is skipped, set is EMPTY !
# plate13_9E is skipped, set is EMPTY !
# plate13_7A is skipped, set is EMPTY !
# plate13_7A is skipped, set is EMPTY !
# plate13_2E is skipped, set is EMPTY !
# plate13_12D is skipped, set is EMPTY !
# plate13_1A is skipped, set is EMPTY !
# plate13_1H is skipped, set is EMPTY !
# plate13_8A is skipped, set is EMPTY !
# plate13_5A is skipped, set is EMPTY !
# plate13_2H is skipped, set is EMPTY !
# plate13_12G is skipped, set is EMPTY !
# plate13_12E is skipped, set is EMPTY !
# plate13_3C is skipped, set is EMPTY !
# plate13_6B is skipped, set is EMPTY !
# plate13_4B is skipped, set is EMPTY !
# plate13_10F is skipped, set is EMPTY !
# plate13_12A is skipped, set is EMPTY !
# plate13_8B is skipped, set is EMPTY !
# plate13_1B is skipped, set is EMPTY !
# plate13_9H is skipped, set is EMPTY !
# plate13_10B is skipped, set is EMPTY !
# plate13_10F is skipped, set is EMPTY !
# plate13_1E is skipped, set is EMPTY !
# plate13_11B is skipped, set is EMPTY !
# plate13_4C is skipped, set is EMPTY !
# plate13_5G is skipped, set is EMPTY !
# plate13_10A is skipped, set is EMPTY !
# plate13_5D is skipped, set is EMPTY !
# plate13_7D is skipped, set is EMPTY !
# plate13_3E is skipped, set is EMPTY !
# plate13_7H is skipped, set is EMPTY !
# plate13_11D is skipped, set is EMPTY !
# plate13_8E is skipped, set is EMPTY !
# plate13_9A is skipped, set is EMPTY !
# plate13_9A is skipped, set is EMPTY !
# plate13_5E is skipped, set is EMPTY !
# plate13_6D is skipped, set is EMPTY !
# plate13_3F is skipped, set is EMPTY !
# plate13_11G is skipped, set is EMPTY !
# plate13_9C is skipped, set is EMPTY !
# plate13_9H is skipped, set is EMPTY !
# plate13_9F is skipped, set is EMPTY !
# plate13_11C is skipped, set is EMPTY !
# plate13_9G is skipped, set is EMPTY !
# plate13_2H is skipped, set is EMPTY !
# plate13_12D is skipped, set is EMPTY !
# plate13_1D is skipped, set is EMPTY !
# plate13_2E is skipped, set is EMPTY !
# plate13_5H is skipped, set is EMPTY !
# plate13_3D is skipped, set is EMPTY !
# plate13_9F is skipped, set is EMPTY !
# plate13_11E is skipped, set is EMPTY !
# plate13_1D is skipped, set is EMPTY !
# plate13_1B is skipped, set is EMPTY !
# plate13_11G is skipped, set is EMPTY !
# plate13_4A is skipped, set is EMPTY !
# plate13_1H is skipped, set is EMPTY !
# plate13_3D is skipped, set is EMPTY !
# plate13_8B is skipped, set is EMPTY !
# plate13_3H is skipped, set is EMPTY !
# plate13_1H is skipped, set is EMPTY !
# plate13_12G is skipped, set is EMPTY !
# plate13_2D is skipped, set is EMPTY !
# plate13_3F is skipped, set is EMPTY !
# plate13_8C is skipped, set is EMPTY !
# plate13_2C is skipped, set is EMPTY !
# plate13_9G is skipped, set is EMPTY !
# plate13_9E is skipped, set is EMPTY !
# plate13_8C is skipped, set is EMPTY !
# plate13_1A is skipped, set is EMPTY !
# plate13_3E is skipped, set is EMPTY !
# plate13_12B is skipped, set is EMPTY !
# plate13_4B is skipped, set is EMPTY !
# plate13_7H is skipped, set is EMPTY !
# plate13_5F is skipped, set is EMPTY !
# plate13_10E is skipped, set is EMPTY !
# plate13_4D is skipped, set is EMPTY !
# plate13_10A is skipped, set is EMPTY !
# plate13_10C is skipped, set is EMPTY !
# plate13_12C is skipped, set is EMPTY !
# plate13_10D is skipped, set is EMPTY !
# plate13_3B is skipped, set is EMPTY !
# plate13_12E is skipped, set is EMPTY !
# plate13_5F is skipped, set is EMPTY !
# plate13_11H is skipped, set is EMPTY !
# plate13_12A is skipped, set is EMPTY !
# plate13_5D is skipped, set is EMPTY !
# plate13_7A is skipped, set is EMPTY !
# plate13_1E is skipped, set is EMPTY !
# plate13_4C is skipped, set is EMPTY !
# plate13_7B is skipped, set is EMPTY !
# plate13_7D is skipped, set is EMPTY !
# plate13_9D is skipped, set is EMPTY !
# plate13_7F is skipped, set is EMPTY !
# plate13_9B is skipped, set is EMPTY !
# plate13_4F is skipped, set is EMPTY !
# plate13_8B is skipped, set is EMPTY !
# plate13_2C is skipped, set is EMPTY !
# plate13_7D is skipped, set is EMPTY !
# plate13_5F is skipped, set is EMPTY !
# plate13_4B is skipped, set is EMPTY !
# plate13_6H is skipped, set is EMPTY !
# plate13_1E is skipped, set is EMPTY !
# plate13_4G is skipped, set is EMPTY !
# plate13_12H is skipped, set is EMPTY !
# plate13_10C is skipped, set is EMPTY !
# plate13_3A is skipped, set is EMPTY !
# plate13_8D is skipped, set is EMPTY !
# plate13_11G is skipped, set is EMPTY !
# plate13_1A is skipped, set is EMPTY !
# plate13_10C is skipped, set is EMPTY !
# plate13_2E is skipped, set is EMPTY !
# plate13_10F is skipped, set is EMPTY !
# plate13_6E is skipped, set is EMPTY !
# plate13_8C is skipped, set is EMPTY !
# plate13_4E is skipped, set is EMPTY !
# plate13_9D is skipped, set is EMPTY !
# plate13_4E is skipped, set is EMPTY !
# plate13_4G is skipped, set is EMPTY !
# plate13_11B is skipped, set is EMPTY !
# plate13_11B is skipped, set is EMPTY !
# plate13_12D is skipped, set is EMPTY !
# plate13_8E is skipped, set is EMPTY !
# plate13_7D is skipped, set is EMPTY !
# plate13_4A is skipped, set is EMPTY !
# plate13_12H is skipped, set is EMPTY !
# plate13_3G is skipped, set is EMPTY !
# plate13_11H is skipped, set is EMPTY !
# plate13_6D is skipped, set is EMPTY !
# plate13_3F is skipped, set is EMPTY !
# plate13_5E is skipped, set is EMPTY !
# plate13_7D is skipped, set is EMPTY !
# plate13_4F is skipped, set is EMPTY !
# plate13_8A is skipped, set is EMPTY !
# plate13_1E is skipped, set is EMPTY !
# plate13_9B is skipped, set is EMPTY !
# plate13_11C is skipped, set is EMPTY !
# plate13_6F is skipped, set is EMPTY !
# plate13_1D is skipped, set is EMPTY !
# plate13_8A is skipped, set is EMPTY !
# plate13_2A is skipped, set is EMPTY !
# plate13_7C is skipped, set is EMPTY !
# plate13_5B is skipped, set is EMPTY !
# plate13_2D is skipped, set is EMPTY !
# plate13_9C is skipped, set is EMPTY !
# plate13_1G is skipped, set is EMPTY !
# plate13_10D is skipped, set is EMPTY !
# plate13_1F is skipped, set is EMPTY !
# plate13_7H is skipped, set is EMPTY !
# plate13_1D is skipped, set is EMPTY !
# plate13_11G is skipped, set is EMPTY !
# plate13_7F is skipped, set is EMPTY !
# plate13_4C is skipped, set is EMPTY !
# plate13_2E is skipped, set is EMPTY !
# plate13_5F is skipped, set is EMPTY !
# plate13_9H is skipped, set is EMPTY !
# plate13_1F is skipped, set is EMPTY !
# plate13_9E is skipped, set is EMPTY !
# plate13_9E is skipped, set is EMPTY !
# plate13_1E is skipped, set is EMPTY !
# plate13_3B is skipped, set is EMPTY !
# plate13_9A is skipped, set is EMPTY !
# plate13_3E is skipped, set is EMPTY !
# plate13_3B is skipped, set is EMPTY !
# plate13_6H is skipped, set is EMPTY !
# plate13_11F is skipped, set is EMPTY !
# plate13_10G is skipped, set is EMPTY !
# plate13_9G is skipped, set is EMPTY !
# plate13_5F is skipped, set is EMPTY !
# plate13_7C is skipped, set is EMPTY !
# plate13_10C is skipped, set is EMPTY !
# plate13_4D is skipped, set is EMPTY !
# plate13_8H is skipped, set is EMPTY !
# plate13_10C is skipped, set is EMPTY !
# plate13_8C is skipped, set is EMPTY !
# plate13_5G is skipped, set is EMPTY !
# plate13_7E is skipped, set is EMPTY !
# plate13_1E is skipped, set is EMPTY !
# plate13_5D is skipped, set is EMPTY !
# plate13_1A is skipped, set is EMPTY !
# plate13_10E is skipped, set is EMPTY !
# plate13_8F is skipped, set is EMPTY !
# plate13_3A is skipped, set is EMPTY !
# plate13_11C is skipped, set is EMPTY !
# plate13_6E is skipped, set is EMPTY !
# plate13_3B is skipped, set is EMPTY !
# plate13_12F is skipped, set is EMPTY !
# plate13_1H is skipped, set is EMPTY !
# plate13_11D is skipped, set is EMPTY !
# plate13_7G is skipped, set is EMPTY !
# plate13_10D is skipped, set is EMPTY !
# plate13_5D is skipped, set is EMPTY !
# plate13_10H is skipped, set is EMPTY !
# plate13_7H is skipped, set is EMPTY !
# plate13_1H is skipped, set is EMPTY !
# plate13_9G is skipped, set is EMPTY !
# plate13_2B is skipped, set is EMPTY !
# plate13_6D is skipped, set is EMPTY !
# plate13_12G is skipped, set is EMPTY !
# plate13_8G is skipped, set is EMPTY !
# plate13_10H is skipped, set is EMPTY !
# plate13_3C is skipped, set is EMPTY !
# plate13_4H is skipped, set is EMPTY !
# plate13_2G is skipped, set is EMPTY !
# plate13_12A is skipped, set is EMPTY !
# plate13_12B is skipped, set is EMPTY !
# plate13_7E is skipped, set is EMPTY !
# plate13_6F is skipped, set is EMPTY !
# plate13_9B is skipped, set is EMPTY !
# plate13_2C is skipped, set is EMPTY !
# plate13_3H is skipped, set is EMPTY !
# plate13_12A is skipped, set is EMPTY !
# plate13_12C is skipped, set is EMPTY !
# plate13_4D is skipped, set is EMPTY !
# plate13_8C is skipped, set is EMPTY !
# plate13_10H is skipped, set is EMPTY !
# plate13_11C is skipped, set is EMPTY !
# plate13_6D is skipped, set is EMPTY !
# plate13_1G is skipped, set is EMPTY !
# plate13_11F is skipped, set is EMPTY !
# plate13_5D is skipped, set is EMPTY !
# plate13_3F is skipped, set is EMPTY !
# plate13_5A is skipped, set is EMPTY !
# plate13_5B is skipped, set is EMPTY !
# plate13_9B is skipped, set is EMPTY !
# plate13_5C is skipped, set is EMPTY !
# plate13_6G is skipped, set is EMPTY !
# plate13_8E is skipped, set is EMPTY !
# plate13_5B is skipped, set is EMPTY !
# plate13_5A is skipped, set is EMPTY !
# plate13_7A is skipped, set is EMPTY !
# plate13_5G is skipped, set is EMPTY !
# plate13_10F is skipped, set is EMPTY !
# plate13_11H is skipped, set is EMPTY !
# plate13_11H is skipped, set is EMPTY !
# plate13_8H is skipped, set is EMPTY !
# plate13_9G is skipped, set is EMPTY !
# plate13_6A is skipped, set is EMPTY !
# plate13_6G is skipped, set is EMPTY !
# plate13_10E is skipped, set is EMPTY !
# plate13_4C is skipped, set is EMPTY !
# plate13_3F is skipped, set is EMPTY !
# plate13_12F is skipped, set is EMPTY !
# plate13_11A is skipped, set is EMPTY !
# plate13_9B is skipped, set is EMPTY !
# plate13_9B is skipped, set is EMPTY !
# plate13_8A is skipped, set is EMPTY !
# plate13_1G is skipped, set is EMPTY !
# plate13_4C is skipped, set is EMPTY !
# plate13_5F is skipped, set is EMPTY !
# plate13_3E is skipped, set is EMPTY !
# plate13_2C is skipped, set is EMPTY !
# plate13_8A is skipped, set is EMPTY !
# plate13_11E is skipped, set is EMPTY !
# plate13_2H is skipped, set is EMPTY !
# plate13_2B is skipped, set is EMPTY !
# plate13_8G is skipped, set is EMPTY !
# plate13_11B is skipped, set is EMPTY !
# plate13_8F is skipped, set is EMPTY !
# plate13_3C is skipped, set is EMPTY !
# plate13_12G is skipped, set is EMPTY !
# plate13_1G is skipped, set is EMPTY !
# plate13_7D is skipped, set is EMPTY !
# plate13_2E is skipped, set is EMPTY !
# plate13_5C is skipped, set is EMPTY !
# plate13_9C is skipped, set is EMPTY !
# plate13_6E is skipped, set is EMPTY !
# plate13_10A is skipped, set is EMPTY !
# plate13_2D is skipped, set is EMPTY !
# plate13_7A is skipped, set is EMPTY !
# plate13_11E is skipped, set is EMPTY !
# plate13_6H is skipped, set is EMPTY !
# plate13_7A is skipped, set is EMPTY !
# plate13_3B is skipped, set is EMPTY !
# plate13_8D is skipped, set is EMPTY !
# plate13_11D is skipped, set is EMPTY !
# plate13_11F is skipped, set is EMPTY !
# plate13_11A is skipped, set is EMPTY !
# plate13_12A is skipped, set is EMPTY !
# plate13_6A is skipped, set is EMPTY !
# plate13_8D is skipped, set is EMPTY !
# plate13_6A is skipped, set is EMPTY !
# plate13_3F is skipped, set is EMPTY !
# plate13_10B is skipped, set is EMPTY !
# plate13_2B is skipped, set is EMPTY !
# plate13_9F is skipped, set is EMPTY !
# plate13_12C is skipped, set is EMPTY !
# plate13_11H is skipped, set is EMPTY !
# plate13_12C is skipped, set is EMPTY !
# plate13_12H is skipped, set is EMPTY !
# plate13_6D is skipped, set is EMPTY !
# plate13_2G is skipped, set is EMPTY !
# plate13_3D is skipped, set is EMPTY !
# plate13_11G is skipped, set is EMPTY !
# plate13_8G is skipped, set is EMPTY !
# plate13_4C is skipped, set is EMPTY !
# plate13_2F is skipped, set is EMPTY !
# plate13_10H is skipped, set is EMPTY !
# plate13_12F is skipped, set is EMPTY !
# plate13_10F is skipped, set is EMPTY !
# plate13_3C is skipped, set is EMPTY !
# plate13_1C is skipped, set is EMPTY !
# plate13_9G is skipped, set is EMPTY !
# plate13_9D is skipped, set is EMPTY !
# plate13_1A is skipped, set is EMPTY !
# plate13_10B is skipped, set is EMPTY !
# plate13_12C is skipped, set is EMPTY !
# plate13_7B is skipped, set is EMPTY !
# plate13_1H is skipped, set is EMPTY !
# plate13_5E is skipped, set is EMPTY !
# plate13_5G is skipped, set is EMPTY !
# plate13_2D is skipped, set is EMPTY !
# plate13_2H is skipped, set is EMPTY !
# plate13_4H is skipped, set is EMPTY !
# plate13_6D is skipped, set is EMPTY !
# plate13_4A is skipped, set is EMPTY !
# plate13_9F is skipped, set is EMPTY !
# plate13_2E is skipped, set is EMPTY !
# plate13_8A is skipped, set is EMPTY !
# plate13_6A is skipped, set is EMPTY !
# plate13_7B is skipped, set is EMPTY !
# plate13_6G is skipped, set is EMPTY !
# plate13_1E is skipped, set is EMPTY !
# plate13_2D is skipped, set is EMPTY !
# plate13_8G is skipped, set is EMPTY !
# plate13_11G is skipped, set is EMPTY !
# plate13_8H is skipped, set is EMPTY !
# plate13_11A is skipped, set is EMPTY !
# plate13_12E is skipped, set is EMPTY !
# plate13_12G is skipped, set is EMPTY !
# plate13_5G is skipped, set is EMPTY !
# plate13_11E is skipped, set is EMPTY !
# plate13_3D is skipped, set is EMPTY !
# plate13_1D is skipped, set is EMPTY !
# plate13_11H is skipped, set is EMPTY !
# plate13_7B is skipped, set is EMPTY !
# plate13_3G is skipped, set is EMPTY !
# plate13_10G is skipped, set is EMPTY !
# plate13_6F is skipped, set is EMPTY !
# plate13_3A is skipped, set is EMPTY !
# plate13_3H is skipped, set is EMPTY !
# plate13_10H is skipped, set is EMPTY !
# plate13_6G is skipped, set is EMPTY !
# plate13_12F is skipped, set is EMPTY !
# plate13_5A is skipped, set is EMPTY !
# plate13_6H is skipped, set is EMPTY !
# plate13_12C is skipped, set is EMPTY !
# plate13_3H is skipped, set is EMPTY !
# plate13_11A is skipped, set is EMPTY !
# plate13_10E is skipped, set is EMPTY !
# plate13_9C is skipped, set is EMPTY !
# plate13_12B is skipped, set is EMPTY !
# plate13_11B is skipped, set is EMPTY !
# plate13_6B is skipped, set is EMPTY !
# plate13_8G is skipped, set is EMPTY !
# plate13_4F is skipped, set is EMPTY !
# plate13_10F is skipped, set is EMPTY !
# plate13_11F is skipped, set is EMPTY !
# plate13_3C is skipped, set is EMPTY !
# plate13_3F is skipped, set is EMPTY !
# plate13_6H is skipped, set is EMPTY !
# plate13_2C is skipped, set is EMPTY !
# plate13_9C is skipped, set is EMPTY !
# plate13_1B is skipped, set is EMPTY !
# plate13_6F is skipped, set is EMPTY !
# plate13_10E is skipped, set is EMPTY !
# plate13_12D is skipped, set is EMPTY !
# plate13_6B is skipped, set is EMPTY !
# plate13_12A is skipped, set is EMPTY !
# plate13_11F is skipped, set is EMPTY !
# plate13_12F is skipped, set is EMPTY !
# plate13_6D is skipped, set is EMPTY !
# plate13_4B is skipped, set is EMPTY !
# plate13_12H is skipped, set is EMPTY !
# plate13_12H is skipped, set is EMPTY !
# plate13_4F is skipped, set is EMPTY !
# plate13_12C is skipped, set is EMPTY !
# plate13_5B is skipped, set is EMPTY !
# plate13_4G is skipped, set is EMPTY !
# plate13_10A is skipped, set is EMPTY !
# plate13_9B is skipped, set is EMPTY !
# plate13_10F is skipped, set is EMPTY !
# plate13_8E is skipped, set is EMPTY !
# plate13_8H is skipped, set is EMPTY !
# plate13_5C is skipped, set is EMPTY !
# plate13_8F is skipped, set is EMPTY !
# plate13_8A is skipped, set is EMPTY !
# plate13_5H is skipped, set is EMPTY !
# plate13_9C is skipped, set is EMPTY !
# plate13_2F is skipped, set is EMPTY !
# plate13_1F is skipped, set is EMPTY !
# plate13_2A is skipped, set is EMPTY !
# plate13_12D is skipped, set is EMPTY !
# plate13_6B is skipped, set is EMPTY !
# plate13_7E is skipped, set is EMPTY !
# plate13_9C is skipped, set is EMPTY !
# plate13_1G is skipped, set is EMPTY !
# plate13_1C is skipped, set is EMPTY !
# plate13_4A is skipped, set is EMPTY !
# plate13_8H is skipped, set is EMPTY !
# plate13_8B is skipped, set is EMPTY !
# plate13_7G is skipped, set is EMPTY !
# plate13_4D is skipped, set is EMPTY !
# plate13_4B is skipped, set is EMPTY !
# plate13_9C is skipped, set is EMPTY !
# plate13_3G is skipped, set is EMPTY !
# plate13_12D is skipped, set is EMPTY !
# plate13_3D is skipped, set is EMPTY !
# plate13_1C is skipped, set is EMPTY !
# plate13_6C is skipped, set is EMPTY !
# plate13_10B is skipped, set is EMPTY !
# plate13_12E is skipped, set is EMPTY !
# plate13_1G is skipped, set is EMPTY !
# plate13_7G is skipped, set is EMPTY !
# plate13_9B is skipped, set is EMPTY !
# plate13_10G is skipped, set is EMPTY !
# plate13_9D is skipped, set is EMPTY !
# plate13_1B is skipped, set is EMPTY !
# plate13_4C is skipped, set is EMPTY !
# plate13_5E is skipped, set is EMPTY !
# plate13_11B is skipped, set is EMPTY !
# plate13_6G is skipped, set is EMPTY !
# plate13_6E is skipped, set is EMPTY !
# plate13_6B is skipped, set is EMPTY !
# plate13_4E is skipped, set is EMPTY !
# plate13_1H is skipped, set is EMPTY !
# plate13_1H is skipped, set is EMPTY !
# plate13_8E is skipped, set is EMPTY !
# plate13_12E is skipped, set is EMPTY !
# plate13_11H is skipped, set is EMPTY !
# plate13_11E is skipped, set is EMPTY !
# plate13_12F is skipped, set is EMPTY !
# plate13_11C is skipped, set is EMPTY !
# plate13_2B is skipped, set is EMPTY !
# plate13_2G is skipped, set is EMPTY !
# plate13_7H is skipped, set is EMPTY !
# plate13_10B is skipped, set is EMPTY !
# plate13_10D is skipped, set is EMPTY !
# plate13_7F is skipped, set is EMPTY !
# plate13_9F is skipped, set is EMPTY !
# plate13_5G is skipped, set is EMPTY !
# plate13_1F is skipped, set is EMPTY !
# plate13_4H is skipped, set is EMPTY !
# plate13_7B is skipped, set is EMPTY !
# plate13_11D is skipped, set is EMPTY !
# plate13_10A is skipped, set is EMPTY !
# plate13_5H is skipped, set is EMPTY !
# plate13_4A is skipped, set is EMPTY !
# plate13_7E is skipped, set is EMPTY !
# plate13_10A is skipped, set is EMPTY !
# plate13_7G is skipped, set is EMPTY !
# plate13_7E is skipped, set is EMPTY !
# plate13_8A is skipped, set is EMPTY !
# plate13_10D is skipped, set is EMPTY !
# plate13_12A is skipped, set is EMPTY !
# plate13_10G is skipped, set is EMPTY !
# plate13_7B is skipped, set is EMPTY !
# plate13_8G is skipped, set is EMPTY !
# plate13_1A is skipped, set is EMPTY !
# plate13_4E is skipped, set is EMPTY !
# plate13_6E is skipped, set is EMPTY !
# plate13_5G is skipped, set is EMPTY !
# plate13_1A is skipped, set is EMPTY !
# plate13_9A is skipped, set is EMPTY !
# plate13_8E is skipped, set is EMPTY !
# plate13_5A is skipped, set is EMPTY !
# plate13_3A is skipped, set is EMPTY !
# plate13_6E is skipped, set is EMPTY !
# plate13_2D is skipped, set is EMPTY !
# plate13_2B is skipped, set is EMPTY !
# plate13_3G is skipped, set is EMPTY !
# plate13_8D is skipped, set is EMPTY !
# plate13_6F is skipped, set is EMPTY !
# plate13_10H is skipped, set is EMPTY !
# plate13_9A is skipped, set is EMPTY !
# plate13_2A is skipped, set is EMPTY !
# plate13_11G is skipped, set is EMPTY !
# plate13_2H is skipped, set is EMPTY !
# plate13_12C is skipped, set is EMPTY !
# plate13_4D is skipped, set is EMPTY !
# plate13_8F is skipped, set is EMPTY !
# plate13_6E is skipped, set is EMPTY !
# plate13_7H is skipped, set is EMPTY !
# plate13_2F is skipped, set is EMPTY !
# plate13_2H is skipped, set is EMPTY !
# plate13_5D is skipped, set is EMPTY !
# plate13_10H is skipped, set is EMPTY !
# plate13_2B is skipped, set is EMPTY !
# plate13_1C is skipped, set is EMPTY !
# plate13_11F is skipped, set is EMPTY !
# plate13_8D is skipped, set is EMPTY !
# plate13_1H is skipped, set is EMPTY !
# plate13_1C is skipped, set is EMPTY !
# plate13_2G is skipped, set is EMPTY !
# plate13_8E is skipped, set is EMPTY !
# plate13_10D is skipped, set is EMPTY !
# plate13_12B is skipped, set is EMPTY !
# plate13_4B is skipped, set is EMPTY !
# plate13_7G is skipped, set is EMPTY !
# plate13_10E is skipped, set is EMPTY !
# plate13_6B is skipped, set is EMPTY !
# plate13_5H is skipped, set is EMPTY !
# plate13_12D is skipped, set is EMPTY !
# plate13_12F is skipped, set is EMPTY !
# plate13_9F is skipped, set is EMPTY !
# plate13_12F is skipped, set is EMPTY !
# plate13_6G is skipped, set is EMPTY !
# plate13_8B is skipped, set is EMPTY !
# plate13_4F is skipped, set is EMPTY !
# plate13_1F is skipped, set is EMPTY !
# plate13_11A is skipped, set is EMPTY !
# plate13_11C is skipped, set is EMPTY !
# plate13_4G is skipped, set is EMPTY !
# plate13_5B is skipped, set is EMPTY !
# plate13_9D is skipped, set is EMPTY !
# plate13_1B is skipped, set is EMPTY !
# plate13_2G is skipped, set is EMPTY !
# plate13_7D is skipped, set is EMPTY !
# plate13_12E is skipped, set is EMPTY !
# plate13_2B is skipped, set is EMPTY !
# plate13_6F is skipped, set is EMPTY !
# plate13_4E is skipped, set is EMPTY !
# plate13_1A is skipped, set is EMPTY !
# plate13_6G is skipped, set is EMPTY !
# plate13_1C is skipped, set is EMPTY !
# plate13_9F is skipped, set is EMPTY !
# plate13_6B is skipped, set is EMPTY !
# plate13_7A is skipped, set is EMPTY !
# plate13_7C is skipped, set is EMPTY !
# plate13_1D is skipped, set is EMPTY !
# plate13_3E is skipped, set is EMPTY !
# plate13_8H is skipped, set is EMPTY !
# plate13_9A is skipped, set is EMPTY !
# plate13_3E is skipped, set is EMPTY !
# plate13_9H is skipped, set is EMPTY !
# plate13_3G is skipped, set is EMPTY !
# plate13_10C is skipped, set is EMPTY !
# plate13_5F is skipped, set is EMPTY !
# plate13_1B is skipped, set is EMPTY !
# plate13_6A is skipped, set is EMPTY !
# plate13_4G is skipped, set is EMPTY !
# plate13_3F is skipped, set is EMPTY !
# plate13_10G is skipped, set is EMPTY !
# plate13_2F is skipped, set is EMPTY !
# plate13_1B is skipped, set is EMPTY !
# plate13_6A is skipped, set is EMPTY !
# plate13_1F is skipped, set is EMPTY !
# plate13_7H is skipped, set is EMPTY !
# plate13_12G is skipped, set is EMPTY !
# plate13_12E is skipped, set is EMPTY !
# plate13_9H is skipped, set is EMPTY !
# plate13_10H is skipped, set is EMPTY !
# plate13_10A is skipped, set is EMPTY !
# plate13_1A is skipped, set is EMPTY !
# plate13_4D is skipped, set is EMPTY !
# plate13_5G is skipped, set is EMPTY !
# plate13_10G is skipped, set is EMPTY !
# plate13_1C is skipped, set is EMPTY !
# plate13_9A is skipped, set is EMPTY !
# plate13_11F is skipped, set is EMPTY !
# plate13_2H is skipped, set is EMPTY !
# plate13_11D is skipped, set is EMPTY !
# plate13_2B is skipped, set is EMPTY !
# plate13_12A is skipped, set is EMPTY !
# plate13_3H is skipped, set is EMPTY !
# plate13_2G is skipped, set is EMPTY !
# plate13_7E is skipped, set is EMPTY !
# plate13_9E is skipped, set is EMPTY !
# plate13_1D is skipped, set is EMPTY !
# plate13_7C is skipped, set is EMPTY !
# plate13_9E is skipped, set is EMPTY !
# plate13_6G is skipped, set is EMPTY !
# plate13_4F is skipped, set is EMPTY !
# plate13_9D is skipped, set is EMPTY !
# plate13_2E is skipped, set is EMPTY !
# plate13_3B is skipped, set is EMPTY !
# plate13_6E is skipped, set is EMPTY !
# plate13_9A is skipped, set is EMPTY !
# plate13_2F is skipped, set is EMPTY !
# plate13_11A is skipped, set is EMPTY !
# plate13_4H is skipped, set is EMPTY !
# plate13_6F is skipped, set is EMPTY !
# plate13_4D is skipped, set is EMPTY !
# plate13_8E is skipped, set is EMPTY !
# plate13_3B is skipped, set is EMPTY !
# plate13_2D is skipped, set is EMPTY !
# plate13_4C is skipped, set is EMPTY !
# plate13_5C is skipped, set is EMPTY !
# plate13_12D is skipped, set is EMPTY !
# plate13_11D is skipped, set is EMPTY !
# plate13_2A is skipped, set is EMPTY !
# plate13_3G is skipped, set is EMPTY !
# plate13_2B is skipped, set is EMPTY !
# plate13_7D is skipped, set is EMPTY !
# plate13_9D is skipped, set is EMPTY !
# plate13_3G is skipped, set is EMPTY !
# plate13_8B is skipped, set is EMPTY !
# plate13_4B is skipped, set is EMPTY !
# plate13_5H is skipped, set is EMPTY !
# plate13_5B is skipped, set is EMPTY !
# plate13_3G is skipped, set is EMPTY !
# plate13_7B is skipped, set is EMPTY !
# plate13_2H is skipped, set is EMPTY !
# plate13_3B is skipped, set is EMPTY !
# plate13_2H is skipped, set is EMPTY !
# plate13_10D is skipped, set is EMPTY !
# plate13_5D is skipped, set is EMPTY !
# plate13_3A is skipped, set is EMPTY !
# plate13_9B is skipped, set is EMPTY !
# plate13_7E is skipped, set is EMPTY !
# plate13_3H is skipped, set is EMPTY !
# plate13_4H is skipped, set is EMPTY !
# plate13_9C is skipped, set is EMPTY !
# plate13_5F is skipped, set is EMPTY !
# plate13_10B is skipped, set is EMPTY !
# plate13_12A is skipped, set is EMPTY !
# plate13_9F is skipped, set is EMPTY !
# plate13_2A is skipped, set is EMPTY !
# plate13_12G is skipped, set is EMPTY !
# plate13_4E is skipped, set is EMPTY !
# plate13_5H is skipped, set is EMPTY !
# plate13_2C is skipped, set is EMPTY !
# plate13_8D is skipped, set is EMPTY !
# plate2_7A is skipped, set is EMPTY !
# plate2_8F is skipped, set is EMPTY !
# plate2_4G is skipped, set is EMPTY !
# plate2_11F is skipped, set is EMPTY !
# plate2_5D is skipped, set is EMPTY !
# plate2_3E is skipped, set is EMPTY !
# plate2_11H is skipped, set is EMPTY !
# plate2_12F is skipped, set is EMPTY !
# plate2_12B is skipped, set is EMPTY !
# plate2_11C is skipped, set is EMPTY !
# plate2_3C is skipped, set is EMPTY !
# plate2_6G is skipped, set is EMPTY !
# plate2_9G is skipped, set is EMPTY !
# plate2_6H is skipped, set is EMPTY !
# plate2_7G is skipped, set is EMPTY !
# plate2_4E is skipped, set is EMPTY !
# plate2_5G is skipped, set is EMPTY !
# plate2_8D is skipped, set is EMPTY !
# plate2_1F is skipped, set is EMPTY !
# plate2_2A is skipped, set is EMPTY !
# plate2_6F is skipped, set is EMPTY !
# plate2_2G is skipped, set is EMPTY !
# plate2_11B is skipped, set is EMPTY !
# plate2_1A is skipped, set is EMPTY !
# plate2_1H is skipped, set is EMPTY !
# plate2_7E is skipped, set is EMPTY !
# plate2_2A is skipped, set is EMPTY !
# plate2_3F is skipped, set is EMPTY !
# plate2_5D is skipped, set is EMPTY !
# plate2_1A is skipped, set is EMPTY !
# plate2_3D is skipped, set is EMPTY !
# plate2_3E is skipped, set is EMPTY !
# plate2_8H is skipped, set is EMPTY !
# plate2_2C is skipped, set is EMPTY !
# plate2_2G is skipped, set is EMPTY !
# plate2_5H is skipped, set is EMPTY !
# plate2_8H is skipped, set is EMPTY !
# plate2_2F is skipped, set is EMPTY !
# plate2_7H is skipped, set is EMPTY !
# plate2_4A is skipped, set is EMPTY !
# plate2_4B is skipped, set is EMPTY !
# plate2_2D is skipped, set is EMPTY !
# plate2_2G is skipped, set is EMPTY !
# plate2_12A is skipped, set is EMPTY !
# plate2_6B is skipped, set is EMPTY !
# plate2_5C is skipped, set is EMPTY !
# plate2_6G is skipped, set is EMPTY !
# plate2_6C is skipped, set is EMPTY !
# plate2_7C is skipped, set is EMPTY !
# plate2_3G is skipped, set is EMPTY !
# plate2_6A is skipped, set is EMPTY !
# plate2_4D is skipped, set is EMPTY !
# plate2_11D is skipped, set is EMPTY !
# plate2_6B is skipped, set is EMPTY !
# plate2_4H is skipped, set is EMPTY !
# plate2_7G is skipped, set is EMPTY !
# plate2_11A is skipped, set is EMPTY !
# plate2_7B is skipped, set is EMPTY !
# plate2_2H is skipped, set is EMPTY !
# plate2_5E is skipped, set is EMPTY !
# plate2_8A is skipped, set is EMPTY !
# plate2_5A is skipped, set is EMPTY !
# plate2_4G is skipped, set is EMPTY !
# plate2_3G is skipped, set is EMPTY !
# plate2_5A is skipped, set is EMPTY !
# plate2_4E is skipped, set is EMPTY !
# plate2_7A is skipped, set is EMPTY !
# plate2_12G is skipped, set is EMPTY !
# plate2_2F is skipped, set is EMPTY !
# plate2_5G is skipped, set is EMPTY !
# plate2_3A is skipped, set is EMPTY !
# plate2_12F is skipped, set is EMPTY !
# plate2_12D is skipped, set is EMPTY !
# plate2_10C is skipped, set is EMPTY !
# plate2_3A is skipped, set is EMPTY !
# plate2_12C is skipped, set is EMPTY !
# plate2_9C is skipped, set is EMPTY !
# plate2_11H is skipped, set is EMPTY !
# plate2_10G is skipped, set is EMPTY !
# plate2_3F is skipped, set is EMPTY !
# plate2_4E is skipped, set is EMPTY !
# plate2_6F is skipped, set is EMPTY !
# plate2_8E is skipped, set is EMPTY !
# plate2_3H is skipped, set is EMPTY !
# plate2_12H is skipped, set is EMPTY !
# plate2_11F is skipped, set is EMPTY !
# plate2_7E is skipped, set is EMPTY !
# plate2_9H is skipped, set is EMPTY !
# plate2_11B is skipped, set is EMPTY !
# plate2_5C is skipped, set is EMPTY !
# plate2_11E is skipped, set is EMPTY !
# plate2_11A is skipped, set is EMPTY !
# ...
# plate2_1B is skipped, set is EMPTY !
# plate2_12A is skipped, set is EMPTY !
# plate2_5C is skipped, set is EMPTY !
# plate2_8F is skipped, set is EMPTY !
# plate2_1A is skipped, set is EMPTY !
# plate2_5F is skipped, set is EMPTY !
# plate2_10E is skipped, set is EMPTY !
# plate2_1H is skipped, set is EMPTY !
# plate2_11G is skipped, set is EMPTY !
# plate2_12E is skipped, set is EMPTY !
# plate2_4E is skipped, set is EMPTY !
# plate2_1F is skipped, set is EMPTY !
# plate2_3E is skipped, set is EMPTY !
# plate2_11E is skipped, set is EMPTY !
# plate2_9C is skipped, set is EMPTY !
# plate2_1C is skipped, set is EMPTY !
# plate2_5H is skipped, set is EMPTY !
# plate2_1D is skipped, set is EMPTY !
# plate2_9F is skipped, set is EMPTY !
# plate2_3G is skipped, set is EMPTY !
# plate2_12D is skipped, set is EMPTY !
# plate2_9D is skipped, set is EMPTY !
# plate2_4B is skipped, set is EMPTY !
# plate2_12F is skipped, set is EMPTY !
# plate2_9B is skipped, set is EMPTY !
# plate2_8H is skipped, set is EMPTY !
# plate2_2A is skipped, set is EMPTY !
# plate2_12B is skipped, set is EMPTY !
# plate2_3D is skipped, set is EMPTY !
# plate2_11H is skipped, set is EMPTY !
# plate2_6H is skipped, set is EMPTY !
# plate2_10G is skipped, set is EMPTY !
# plate2_9B is skipped, set is EMPTY !
# plate2_1C is skipped, set is EMPTY !
# plate2_5G is skipped, set is EMPTY !
# plate2_2A is skipped, set is EMPTY !
# plate2_6F is skipped, set is EMPTY !
# plate2_10C is skipped, set is EMPTY !
# plate2_6G is skipped, set is EMPTY !
# plate2_6B is skipped, set is EMPTY !
# plate2_10D is skipped, set is EMPTY !
# plate2_4C is skipped, set is EMPTY !
# plate2_12B is skipped, set is EMPTY !
# plate2_4B is skipped, set is EMPTY !
# plate2_7B is skipped, set is EMPTY !
# plate2_2H is skipped, set is EMPTY !
# plate2_6G is skipped, set is EMPTY !
# plate2_1A is skipped, set is EMPTY !
# plate2_3G is skipped, set is EMPTY !
# plate2_3H is skipped, set is EMPTY !
# plate2_8A is skipped, set is EMPTY !
# plate2_10C is skipped, set is EMPTY !
# plate2_12B is skipped, set is EMPTY !
# plate2_4F is skipped, set is EMPTY !
# plate2_7F is skipped, set is EMPTY !
# plate2_2E is skipped, set is EMPTY !
# plate2_9E is skipped, set is EMPTY !
# plate2_5A is skipped, set is EMPTY !
# plate2_2H is skipped, set is EMPTY !
# plate2_11D is skipped, set is EMPTY !
# plate2_5A is skipped, set is EMPTY !
# plate2_3H is skipped, set is EMPTY !
# plate2_6C is skipped, set is EMPTY !
# plate2_11C is skipped, set is EMPTY !
# plate2_5H is skipped, set is EMPTY !
# plate2_12H is skipped, set is EMPTY !
# plate2_3F is skipped, set is EMPTY !
# plate2_7F is skipped, set is EMPTY !
# plate2_8F is skipped, set is EMPTY !
# plate2_1F is skipped, set is EMPTY !
# plate2_5E is skipped, set is EMPTY !
# plate2_8A is skipped, set is EMPTY !
# plate2_7D is skipped, set is EMPTY !
# plate2_1E is skipped, set is EMPTY !
# plate2_9B is skipped, set is EMPTY !
# plate2_6H is skipped, set is EMPTY !
# plate2_3B is skipped, set is EMPTY !
# plate2_5A is skipped, set is EMPTY !
# plate2_10E is skipped, set is EMPTY !
# plate2_5F is skipped, set is EMPTY !
# plate2_3D is skipped, set is EMPTY !
# plate2_1H is skipped, set is EMPTY !
# plate2_2A is skipped, set is EMPTY !
# plate2_11G is skipped, set is EMPTY !
# plate2_8F is skipped, set is EMPTY !
# plate2_4A is skipped, set is EMPTY !
# plate2_11G is skipped, set is EMPTY !
# plate2_11C is skipped, set is EMPTY !
# plate2_3G is skipped, set is EMPTY !
# plate2_7H is skipped, set is EMPTY !
# plate2_8G is skipped, set is EMPTY !
# plate2_9E is skipped, set is EMPTY !
# plate2_8A is skipped, set is EMPTY !
# plate2_2D is skipped, set is EMPTY !
# plate2_6A is skipped, set is EMPTY !
# plate2_6E is skipped, set is EMPTY !
# plate2_7C is skipped, set is EMPTY !
# plate2_9B is skipped, set is EMPTY !
# plate2_5C is skipped, set is EMPTY !
# plate2_5A is skipped, set is EMPTY !
# plate2_4A is skipped, set is EMPTY !
# plate2_8A is skipped, set is EMPTY !
# plate2_7G is skipped, set is EMPTY !
# plate2_12B is skipped, set is EMPTY !
# plate2_1B is skipped, set is EMPTY !
# plate2_1H is skipped, set is EMPTY !
# plate2_11H is skipped, set is EMPTY !
# plate2_12B is skipped, set is EMPTY !
# plate2_9F is skipped, set is EMPTY !
# plate2_9C is skipped, set is EMPTY !
# plate2_1B is skipped, set is EMPTY !
# plate2_5D is skipped, set is EMPTY !
# plate2_4H is skipped, set is EMPTY !
# plate2_8H is skipped, set is EMPTY !
# plate2_12G is skipped, set is EMPTY !
# plate2_8B is skipped, set is EMPTY !
# plate2_7D is skipped, set is EMPTY !
# plate2_5B is skipped, set is EMPTY !
# plate2_3F is skipped, set is EMPTY !
# plate2_8B is skipped, set is EMPTY !
# plate2_3D is skipped, set is EMPTY !
# plate2_6C is skipped, set is EMPTY !
# plate2_12A is skipped, set is EMPTY !
# plate2_3D is skipped, set is EMPTY !
# plate2_2B is skipped, set is EMPTY !
# plate2_10A is skipped, set is EMPTY !
# plate2_2E is skipped, set is EMPTY !
# plate2_6D is skipped, set is EMPTY !
# plate2_9B is skipped, set is EMPTY !
# plate2_10D is skipped, set is EMPTY !
# plate2_3G is skipped, set is EMPTY !
# plate2_9G is skipped, set is EMPTY !
# plate2_3A is skipped, set is EMPTY !
# plate2_6A is skipped, set is EMPTY !
# plate2_12F is skipped, set is EMPTY !
# plate2_9A is skipped, set is EMPTY !
# plate2_7H is skipped, set is EMPTY !
# plate2_11D is skipped, set is EMPTY !
# plate2_10F is skipped, set is EMPTY !
# plate2_1G is skipped, set is EMPTY !
# plate2_9A is skipped, set is EMPTY !
# plate2_9H is skipped, set is EMPTY !
# plate2_7F is skipped, set is EMPTY !
# plate2_8G is skipped, set is EMPTY !
# plate2_10B is skipped, set is EMPTY !
# plate2_8C is skipped, set is EMPTY !
# plate2_5C is skipped, set is EMPTY !
# plate2_2E is skipped, set is EMPTY !
# plate2_9A is skipped, set is EMPTY !
# plate2_11H is skipped, set is EMPTY !
# plate2_10E is skipped, set is EMPTY !
# plate2_1F is skipped, set is EMPTY !
# plate2_7E is skipped, set is EMPTY !
# plate2_9F is skipped, set is EMPTY !
# plate2_9H is skipped, set is EMPTY !
# plate2_7G is skipped, set is EMPTY !
# plate2_6D is skipped, set is EMPTY !
# plate2_10D is skipped, set is EMPTY !
# plate2_9B is skipped, set is EMPTY !
# plate2_2B is skipped, set is EMPTY !
# plate2_12D is skipped, set is EMPTY !
# plate2_1G is skipped, set is EMPTY !
# plate2_12C is skipped, set is EMPTY !
# plate2_1D is skipped, set is EMPTY !
# plate2_7F is skipped, set is EMPTY !
# plate2_7F is skipped, set is EMPTY !
# plate2_9H is skipped, set is EMPTY !
# plate2_5D is skipped, set is EMPTY !
# plate2_8B is skipped, set is EMPTY !
# plate2_9E is skipped, set is EMPTY !
# plate2_9E is skipped, set is EMPTY !
# plate2_3E is skipped, set is EMPTY !
# plate2_7D is skipped, set is EMPTY !
# plate2_9C is skipped, set is EMPTY !
# plate2_2E is skipped, set is EMPTY !
# plate2_9D is skipped, set is EMPTY !
# plate2_7H is skipped, set is EMPTY !
# plate2_8C is skipped, set is EMPTY !
# plate2_10D is skipped, set is EMPTY !
# plate2_5D is skipped, set is EMPTY !
# plate2_12G is skipped, set is EMPTY !
# plate2_4F is skipped, set is EMPTY !
# plate2_10G is skipped, set is EMPTY !
# plate2_7H is skipped, set is EMPTY !
# plate2_1E is skipped, set is EMPTY !
# plate2_4G is skipped, set is EMPTY !
# plate2_6B is skipped, set is EMPTY !
# plate2_12G is skipped, set is EMPTY !
# plate2_11D is skipped, set is EMPTY !
# plate2_5G is skipped, set is EMPTY !
# plate2_7E is skipped, set is EMPTY !
# plate2_11B is skipped, set is EMPTY !
# plate2_7A is skipped, set is EMPTY !
# plate2_6D is skipped, set is EMPTY !
# plate2_9H is skipped, set is EMPTY !
# plate2_5F is skipped, set is EMPTY !
# plate2_5B is skipped, set is EMPTY !
# plate2_8B is skipped, set is EMPTY !
# plate2_12F is skipped, set is EMPTY !
# plate2_1G is skipped, set is EMPTY !
# plate2_6C is skipped, set is EMPTY !
# plate2_10C is skipped, set is EMPTY !
# plate2_2A is skipped, set is EMPTY !
# plate2_1A is skipped, set is EMPTY !
# plate2_10G is skipped, set is EMPTY !
# plate2_9F is skipped, set is EMPTY !
# plate2_5E is skipped, set is EMPTY !
# plate2_11C is skipped, set is EMPTY !
# plate2_11C is skipped, set is EMPTY !
# plate2_11H is skipped, set is EMPTY !
# plate2_12H is skipped, set is EMPTY !
# plate2_1E is skipped, set is EMPTY !
# plate2_10D is skipped, set is EMPTY !
# plate2_7D is skipped, set is EMPTY !
# plate2_5A is skipped, set is EMPTY !
# plate2_5D is skipped, set is EMPTY !
# plate2_5G is skipped, set is EMPTY !
# plate2_1E is skipped, set is EMPTY !
# plate2_10A is skipped, set is EMPTY !
# plate2_11B is skipped, set is EMPTY !
# plate2_1F is skipped, set is EMPTY !
# plate2_10B is skipped, set is EMPTY !
# plate2_11A is skipped, set is EMPTY !
# plate2_5F is skipped, set is EMPTY !
# plate2_1F is skipped, set is EMPTY !
# plate2_10H is skipped, set is EMPTY !
# plate2_2E is skipped, set is EMPTY !
# plate2_3H is skipped, set is EMPTY !
# plate2_1F is skipped, set is EMPTY !
# plate2_12E is skipped, set is EMPTY !
# plate2_7G is skipped, set is EMPTY !
# plate2_3D is skipped, set is EMPTY !
# plate2_8A is skipped, set is EMPTY !
# plate2_5F is skipped, set is EMPTY !
# plate2_9G is skipped, set is EMPTY !
# plate2_6H is skipped, set is EMPTY !
# plate2_9G is skipped, set is EMPTY !
# plate2_8E is skipped, set is EMPTY !
# plate2_10A is skipped, set is EMPTY !
# plate2_5G is skipped, set is EMPTY !
# plate2_7H is skipped, set is EMPTY !
# plate2_1D is skipped, set is EMPTY !
# plate2_10G is skipped, set is EMPTY !
# plate2_12E is skipped, set is EMPTY !
# plate2_11F is skipped, set is EMPTY !
# plate2_4H is skipped, set is EMPTY !
# plate2_11F is skipped, set is EMPTY !
# plate2_7C is skipped, set is EMPTY !
# plate2_4D is skipped, set is EMPTY !
# plate2_11G is skipped, set is EMPTY !
# plate2_5F is skipped, set is EMPTY !
# plate2_10H is skipped, set is EMPTY !
# plate2_12F is skipped, set is EMPTY !
# plate2_11C is skipped, set is EMPTY !
# plate2_5B is skipped, set is EMPTY !
# plate2_8D is skipped, set is EMPTY !
# plate2_3E is skipped, set is EMPTY !
# plate2_4A is skipped, set is EMPTY !
# plate2_11G is skipped, set is EMPTY !
# plate2_2H is skipped, set is EMPTY !
# plate2_5C is skipped, set is EMPTY !
# plate2_6G is skipped, set is EMPTY !
# plate2_11G is skipped, set is EMPTY !
# plate2_4F is skipped, set is EMPTY !
# plate2_9D is skipped, set is EMPTY !
# plate2_2C is skipped, set is EMPTY !
# plate2_1F is skipped, set is EMPTY !
# plate2_1H is skipped, set is EMPTY !
# plate2_10F is skipped, set is EMPTY !
# plate2_1G is skipped, set is EMPTY !
# plate2_8F is skipped, set is EMPTY !
# plate2_7C is skipped, set is EMPTY !
# plate2_12E is skipped, set is EMPTY !
# plate2_3B is skipped, set is EMPTY !
# plate2_8H is skipped, set is EMPTY !
# plate2_4D is skipped, set is EMPTY !
# plate2_2F is skipped, set is EMPTY !
# plate2_4B is skipped, set is EMPTY !
# plate2_12C is skipped, set is EMPTY !
# plate2_1G is skipped, set is EMPTY !
# plate2_6G is skipped, set is EMPTY !
# plate2_8G is skipped, set is EMPTY !
# plate2_12D is skipped, set is EMPTY !
# plate2_1E is skipped, set is EMPTY !
# plate2_8G is skipped, set is EMPTY !
# plate2_9H is skipped, set is EMPTY !
# plate2_3B is skipped, set is EMPTY !
# plate2_9G is skipped, set is EMPTY !
# plate2_3A is skipped, set is EMPTY !
# plate2_5B is skipped, set is EMPTY !
# plate2_10F is skipped, set is EMPTY !
# plate2_5D is skipped, set is EMPTY !
# plate2_6G is skipped, set is EMPTY !
# plate2_10G is skipped, set is EMPTY !
# plate2_3G is skipped, set is EMPTY !
# plate2_10H is skipped, set is EMPTY !
# plate2_1B is skipped, set is EMPTY !
# plate2_1H is skipped, set is EMPTY !
# plate2_10F is skipped, set is EMPTY !
# plate2_2D is skipped, set is EMPTY !
# plate2_5E is skipped, set is EMPTY !
# plate2_11F is skipped, set is EMPTY !
# plate2_1G is skipped, set is EMPTY !
# plate2_6F is skipped, set is EMPTY !
# plate2_2H is skipped, set is EMPTY !
# plate2_10A is skipped, set is EMPTY !
# plate2_7E is skipped, set is EMPTY !
# plate2_9B is skipped, set is EMPTY !
# plate2_12F is skipped, set is EMPTY !
# plate2_7D is skipped, set is EMPTY !
# plate2_9C is skipped, set is EMPTY !
# plate2_7B is skipped, set is EMPTY !
# plate2_1B is skipped, set is EMPTY !
# plate2_6D is skipped, set is EMPTY !
# plate2_8E is skipped, set is EMPTY !
# plate2_4F is skipped, set is EMPTY !
# plate2_12F is skipped, set is EMPTY !
# plate2_10E is skipped, set is EMPTY !
# plate2_4G is skipped, set is EMPTY !
# plate2_11G is skipped, set is EMPTY !
# plate2_11D is skipped, set is EMPTY !
# plate2_9C is skipped, set is EMPTY !
# plate2_4A is skipped, set is EMPTY !
# plate2_5B is skipped, set is EMPTY !
# plate2_2D is skipped, set is EMPTY !
# plate2_5B is skipped, set is EMPTY !
# plate2_3C is skipped, set is EMPTY !
# plate2_8B is skipped, set is EMPTY !
# plate2_9A is skipped, set is EMPTY !
# plate2_2D is skipped, set is EMPTY !
# plate2_5E is skipped, set is EMPTY !
# plate2_5F is skipped, set is EMPTY !
# plate2_11A is skipped, set is EMPTY !
# plate2_3E is skipped, set is EMPTY !
# plate2_10F is skipped, set is EMPTY !
# plate2_10E is skipped, set is EMPTY !
# plate2_3H is skipped, set is EMPTY !
# plate2_7C is skipped, set is EMPTY !
# plate2_6H is skipped, set is EMPTY !
# plate2_8A is skipped, set is EMPTY !
# plate2_2B is skipped, set is EMPTY !
# plate2_10H is skipped, set is EMPTY !
# plate2_3B is skipped, set is EMPTY !
# plate2_10F is skipped, set is EMPTY !
# plate2_3D is skipped, set is EMPTY !
# plate2_4C is skipped, set is EMPTY !
# plate2_3D is skipped, set is EMPTY !
# plate2_3C is skipped, set is EMPTY !
# plate2_8H is skipped, set is EMPTY !
# plate2_8C is skipped, set is EMPTY !
# plate2_3H is skipped, set is EMPTY !
# plate2_1D is skipped, set is EMPTY !
# plate2_6H is skipped, set is EMPTY !
# plate2_10E is skipped, set is EMPTY !
# plate2_3B is skipped, set is EMPTY !
# plate2_2C is skipped, set is EMPTY !
# plate2_3B is skipped, set is EMPTY !
# plate2_4B is skipped, set is EMPTY !
# plate2_12E is skipped, set is EMPTY !
# plate2_8H is skipped, set is EMPTY !
# plate2_4E is skipped, set is EMPTY !
# plate2_12C is skipped, set is EMPTY !
# plate2_4E is skipped, set is EMPTY !
# plate2_7C is skipped, set is EMPTY !
# plate2_8A is skipped, set is EMPTY !
# plate2_2F is skipped, set is EMPTY !
# plate2_3C is skipped, set is EMPTY !
# plate2_2G is skipped, set is EMPTY !
# plate2_9H is skipped, set is EMPTY !
# plate2_2H is skipped, set is EMPTY !
# plate2_1A is skipped, set is EMPTY !
# plate2_3A is skipped, set is EMPTY !
# plate2_8D is skipped, set is EMPTY !
# plate2_6B is skipped, set is EMPTY !
# plate2_4G is skipped, set is EMPTY !
# plate2_4H is skipped, set is EMPTY !
# plate2_3H is skipped, set is EMPTY !
# plate2_1C is skipped, set is EMPTY !
# plate2_10F is skipped, set is EMPTY !
# plate2_11D is skipped, set is EMPTY !
# plate2_10G is skipped, set is EMPTY !
# plate2_7B is skipped, set is EMPTY !
# plate2_3F is skipped, set is EMPTY !
# plate2_11C is skipped, set is EMPTY !
# plate2_5D is skipped, set is EMPTY !
# plate2_2F is skipped, set is EMPTY !
# plate2_7E is skipped, set is EMPTY !
# plate2_2F is skipped, set is EMPTY !
# plate2_3C is skipped, set is EMPTY !
# plate2_8C is skipped, set is EMPTY !
# plate2_9E is skipped, set is EMPTY !
# plate2_8B is skipped, set is EMPTY !
# plate2_4H is skipped, set is EMPTY !
# plate2_6H is skipped, set is EMPTY !
# plate2_11B is skipped, set is EMPTY !
# plate2_2B is skipped, set is EMPTY !
# plate2_5C is skipped, set is EMPTY !
# plate2_8D is skipped, set is EMPTY !
# plate2_10F is skipped, set is EMPTY !
# plate2_4D is skipped, set is EMPTY !
# plate2_11F is skipped, set is EMPTY !
# plate2_4B is skipped, set is EMPTY !
# plate2_11E is skipped, set is EMPTY !
# plate2_7B is skipped, set is EMPTY !
# plate2_9D is skipped, set is EMPTY !
# plate2_1G is skipped, set is EMPTY !
# plate2_6E is skipped, set is EMPTY !
# plate2_10E is skipped, set is EMPTY !
# plate2_5H is skipped, set is EMPTY !
# plate2_6C is skipped, set is EMPTY !
# plate2_5G is skipped, set is EMPTY !
# plate2_10B is skipped, set is EMPTY !
# plate2_7B is skipped, set is EMPTY !
# plate2_7A is skipped, set is EMPTY !
# plate2_12E is skipped, set is EMPTY !
# plate2_6E is skipped, set is EMPTY !
# plate2_1B is skipped, set is EMPTY !
# plate2_6E is skipped, set is EMPTY !

# %%
import napari_spatialdata
napari_spatialdata.Interactive(sdata)

# %%
import pandas as pd

rows = [(k, v_i) for k, v in collectedTiles.items() for v_i in v]

barcode_key_paired_df = pd.DataFrame(rows, columns=["key", "value"])


# First, ensure the 'key' column is string type
barcode_key_paired_df["key"] = barcode_key_paired_df["key"].astype(str)

# Split the key column into two parts using '_col_' as the separator
split_df = barcode_key_paired_df["key"].str.split("_col_", expand=True)

# Assign the new columns
split_df.columns = ["Tile", "Clone"]

# Create the final DataFrame
final_df = pd.DataFrame({
    "cell_id": barcode_key_paired_df["value"],         # or use barcode_key_paired_df["some_id_column"] if index is not cell_id
    "Tile": split_df["Tile"],
    "Clone": split_df["Clone"],
})

final_df.to_csv("Barcode_TileClone_Pair.V2.csv", index=False)

# %%
tiles_shapes = sdata.shapes["tiles"]["color"].apply(lambda x: "_".join(map(str, x))).copy()
sdata.shapes["tiles"]["color_joined"] = tiles_shapes

# %%
from collections import Counter
Counter(sdata.shapes["tiles"]["color_joined"])

# %%
import napari_spatialdata

# sdata.shapes["tiles"]["color_joined"] = (
#     sdata.shapes["tiles"]["color_joined"]
#     .apply(lambda c: c if c == "0_0_0" else "red")
# )

napari_spatialdata.Interactive(sdata)

# %%
# #poi = sdata["tiles"].geometry.iloc[0]
# poi = sdata["POI"].geometry.iloc[0]
# sdata_tile_oi = polygon_query(sdata, polygon=poi, target_coordinate_system="aligned")

# len(polygon_query(sdata, polygon=sdata.shapes["POI_2"].geometry.iloc[4], target_coordinate_system="aligned").shapes["cell_boundaries"].index.to_list())
# len(polygon_query(sdata, polygon=sdata.shapes["tiles"].geometry.iloc[0], target_coordinate_system="aligned").shapes["cell_boundaries"].index.to_list())

# sdata.shapes["tiles"] = sdata.shapes["tiles"].iloc[[0,1,2,3,4]]

# %%
# transf = spatialdata.transformations.get_transformation_between_coordinate_systems(sdata, 'pixels', 'global', intermediate_coordinate_systems=sdata.images['_20221020095443.ome'])
# transf
